# %%
import os
from dotenv import load_dotenv
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
from google.adk.tools import google_search, AgentTool, FunctionTool
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.agents import Agent, SequentialAgent, LoopAgent, ParallelAgent
from google.genai import types

# %%
retry_configs = types.HttpRetryOptions(
    attempts=5,
    initial_delay=1,
    exp_base=7,
    http_status_codes=[429,500,503,504]
)

# %% [markdown]
# <img width="800" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/multi-agent-team.png" alt="Multi-agent Team" />

# %%
research_agent = Agent(
    name="research_agent",
    model=Gemini(model='gemini-2.5-flash', retry_options=retry_configs),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings"
)

# %%
summarizer_agent = Agent(
    name="summarizer_agent",
    model=Gemini(model='gemini-2.5-flash', retry_options=retry_configs),
    instruction="""Read and profind research findings {research_findings}
    Create a concise summary as a bulleted list with 3-5 key points."""   ,
    output_key="final_summary"
)

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="research_coordinator",
    model=Gemini(model='gemini-2.5-flash', retry_options=retry_configs),
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
    1. First, you MUST call the `research_agent` tool to find relevant information on the topic provided by the user.
    2. Next, after receiving the research findings, you MUST call the `summarizer_agent` tool to create a concise summary.
    3. Finally, present the final summary clearly to the user as your response.""",
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)]
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("list all features in latest ubuntu update.")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poojan/programs/personal-programs/5dgai/.venv/lib/python3.11/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > list all features in latest ubuntu update.
# Warning: there are non-text parts in the response: ['function_call', 'thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poojan/programs/personal-programs/5dgai/.venv/lib/python3.11/site-packages/google/adk/agents", which implies app name "agents".
# Warning: there are non-text parts in the response: ['function_call', 'thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poojan/programs/personal-programs/5dgai/.venv/lib/python3.11/site-packages/google/adk/agents", which implies app name "agents".
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# research_coordinator > Here's a concise summary of the latest Ubuntu updates:
#
# *   **Ubuntu 25.10 "Questing Quokka"** (Oct 2025) fully transitions to Wayland, enhances security with Rust-based `sudo` and experimental TPM encryption, and improves NVIDIA driver stability.
# *   **Ubuntu 24.04 LTS "Noble Numbat"** (Apr 2024) offers extended support (up to 12 years with Pro), features a redesigned Flutter-based installer and App Center, and adopts Pipewire as the default sound server.
# *   Both releases include updated Linux kernels and GNOME desktop environments, bringing UI refinements, performance enhancements, and improved hardware support.
# *   Ubuntu 24.04 LTS further introduces advanced window tiling, updated developer toolchains, and a dedicated firmware updater.

# %% [markdown]
# ##### Let's do it in better way

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgnet",
    model=Gemini(model = 'gemini-2.5-flash', retry_options=retry_configs),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought
    5. Always use google search tool for latest information""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
    tools=[google_search]
)

# %%
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(model = 'gemini-2.5-flash', retry_options=retry_configs),
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.
    Use google search for latest information""",
    output_key="blog_draft",
    # tools=[google_search]
)

# %%
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(model = 'gemini-2.5-flash', retry_options=retry_configs),
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog"
)

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent]
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poojan/programs/personal-programs/5dgai/.venv/lib/python3.11/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgnet > ## Unleash Collaborative Intelligence: Why Multi-Agent Systems Are Your Next Development Superpower
#
# ### Introduction Hook
# Modern software development is increasingly complex, demanding solutions that can handle intricate problems, dynamic environments, and rapid changes. While single AI models have made significant strides, a new paradigm is emerging: Multi-Agent Systems (MAS). These systems, composed of multiple autonomous AI agents collaborating to achieve shared goals, are revolutionizing how software is built, tested, and delivered. In fact, Gartner predicts that by 2028, AI agents will autonomously handle at least 15% of workplace decisions, ranking AI agents first on Gartner's list of top Strategic Technology Trends for 2025. For software developers, understanding and leveraging MAS is no longer optional—it's a competitive edge.
#
# ### 1. Tackling Complexity with Specialized Intelligence
# Multi-Agent Systems excel at dissecting and conquering challenges that overwhelm monolithic approaches by distributing cognitive load.
# *   **Complex Problem Decomposition:** MAS breaks down large, intricate problems into smaller, manageable subtasks, each assigned to a specialized agent. This distributed approach allows for attacking goals that single agents or impracticable algorithms cannot.
# *   **Specialization and Expertise:** Each agent can be designed with a focused skillset and knowledge base, leading to deeper expertise and more accurate, high-quality solutions for specific aspects of a problem.
# *   **Enhanced Contextualization:** A well-designed MAS can integrate company-specific code, documentation, technical standards, and internal knowledge sources, ensuring highly contextualized and relevant answers and solutions tailored to project needs.
#
# ### 2. Boosting Efficiency and Productivity
# MAS significantly streamlines the development lifecycle by automating tasks and enabling parallel execution, leading to faster delivery and improved output.
# *   **Automation of Repetitive Tasks:** AI agents can handle repetitive or low-value tasks throughout the software development cycle, such as code generation, testing, and documentation, freeing developers to focus on higher-level design and innovation.
# *   **Parallel Processing & Concurrency:** With multiple agents working simultaneously on different parts of a problem, MAS enables parallel processing, drastically speeding up overall problem-solving and computation, which is infeasible for a single agent.
# *   **Reduced Cognitive Load:** By offloading complex details and intricate workflows to specialized agents, developers experience a reduced cognitive burden, allowing them to concentrate on critical thinking and creative problem-solving.
#
# ### 3. Enhanced Scalability and Robustness
# The decentralized nature of Multi-Agent Systems brings inherent advantages in terms of growth and resilience.
# *   **Distributed Workload & Scalability:** MAS are designed for modularity and can scale effortlessly. Adding or removing agents dynamically is far easier than scaling a monolithic system, making them ideal for handling increased user requests or expanding project scopes.
# *   **Fault Tolerance and Resilience:** Since agents operate independently, the failure of one component does not cripple the entire system. Other agents can often continue working or adapt, ensuring higher availability and reliability.
# *   **Adaptability to Dynamic Environments:** Agents within a MAS can continuously learn and adapt their behaviors based on real-time environmental changes, making them highly suitable for unpredictable and evolving real-world applications.
#
# ### 4. Fostering a Superior Developer Experience
# Multi-Agent Systems improve the development process itself, making it more collaborative and efficient for teams.
# *   **Improved Collaboration and Communication:** MAS platforms facilitate seamless communication and coordination among agents, mirroring a well-orchestrated human development team and enhancing the overall collaborative intelligence.
# *   **Modularity and Reusability:** Specialized agents, once built, can be reused across different applications and projects. This modularity saves development time, ensures consistency, and allows for easier updates without breaking other system components.
# *   **Accelerated Legacy System Modernization:** MAS can employ intelligent agents to analyze, interpret, and transform legacy systems into modern, scalable solutions through automation and contextualization, significantly reducing modernization time and costs.
#
# ### Concluding Thought
# Multi-Agent Systems represent a significant breakthrough in software development, moving beyond individual AI capabilities to harness the power of collaborative intelligence. By embracing this architectural evolution, developers can tackle more complex problems, boost efficiency, build more robust and scalable applications, and ultimately elevate their entire development experience. The future of software is collaborative, autonomous, and undeniably multi-agent.
# WriterAgent > ## Unleash Collaborative Intelligence: Why Multi-Agent Systems Are Your Next Development Superpower
#
# Modern software development is a labyrinth of complexity, demanding innovative solutions for dynamic problems. While single AI models have made impressive strides, a new paradigm is redefining the landscape: Multi-Agent Systems (MAS). These systems, composed of multiple autonomous AI agents collaborating to achieve shared goals, are revolutionizing how we build, test, and deliver software. Gartner even predicts that by 2028, AI agents will autonomously handle at least 15% of workplace decisions, ranking them first on their list of top Strategic Technology Trends for 2025. For forward-thinking developers, leveraging MAS is becoming an essential competitive advantage.
#
# MAS excels at tackling intricate challenges by distributing cognitive load. They break down complex problems into manageable subtasks, each assigned to a specialized agent with focused expertise. This allows for highly contextualized solutions by integrating company-specific knowledge. Beyond problem-solving, MAS dramatically boosts efficiency. Agents automate repetitive tasks like code generation and testing, freeing developers for higher-value innovation. Parallel processing further accelerates development, while reducing cognitive load on human teams.
#
# The decentralized nature of MAS also ensures superior scalability and robustness. Systems can effortlessly scale by adding or removing agents, and their inherent fault tolerance means a single agent's failure won't cripple the entire operation. Agents continually learn and adapt to dynamic environments, making applications more resilient. Furthermore, MAS fosters a better developer experience through improved agent collaboration, modularity, and reusability, even accelerating legacy system modernization.
#
# In essence, Multi-Agent Systems represent a profound architectural evolution. By harnessing collaborative intelligence, developers can conquer greater complexities, achieve unprecedented efficiency, build resilient applications, and fundamentally elevate their entire development journey. The future of software is undeniably collaborative, autonomous, and multi-agent.
# EditorAgent > Here's the polished draft, focusing on clarity, flow, and grammatical correctness:
#
# ## Unleash Collaborative Intelligence: Why Multi-Agent Systems Are Your Next Development Superpower
#
# Modern software development navigates a labyrinth of complexity, demanding innovative solutions for dynamic problems. While single AI models have made impressive strides, a new paradigm is redefining the landscape: Multi-Agent Systems (MAS). These systems, composed of multiple autonomous AI agents collaborating to achieve shared goals, are revolutionizing how we build, test, and deliver software. In fact, Gartner predicts that by 2028, AI agents will autonomously handle at least 15% of workplace decisions, ranking AI agents first on its list of top Strategic Technology Trends for 2025. For forward-thinking developers, leveraging MAS is becoming an essential competitive advantage.
#
# MAS excels at tackling intricate challenges by distributing cognitive load. They break down complex problems into manageable subtasks, each assigned to a specialized agent with focused expertise. This distributed approach allows for highly contextualized solutions by integrating company-specific knowledge. Beyond problem-solving, MAS dramatically boosts efficiency. Agents automate repetitive tasks like code generation and testing, freeing developers for higher-value innovation. Parallel processing further accelerates development, while reducing cognitive load on human teams.
#
# The decentralized nature of MAS also ensures superior scalability and robustness. Systems can effortlessly scale by adding or removing agents, and their inherent fault tolerance means a single agent's failure won't cripple the entire operation. Agents continually learn and adapt to dynamic environments, making applications more resilient and capable of handling unpredictable real-world scenarios.
#
# Furthermore, MAS fosters a superior developer experience by improving agent collaboration, promoting modularity, and enhancing reusability. Specialized agents, once built, can be reused across different applications and projects, saving significant development time and ensuring consistency. MAS can even accelerate legacy system modernization by employing intelligent agents to analyze, interpret, and transform older systems into modern, scalable solutions.
#
# In essence, Multi-Agent Systems represent a profound architectural evolution. By harnessing collaborative intelligence, developers can conquer greater complexities, achieve unprecedented efficiency, build resilient applications, and fundamentally elevate their entire development journey. The future of software is undeniably collaborative, autonomous, and multi-agent.

# %% [markdown]
# #### Parallel Workflows - Independent Researchers

# %% [markdown]
# <img width="600" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/parallel-agent.png" alt="Parallel Agent" />

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary"
)

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher]
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent]
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poojan/programs/personal-programs/5dgai/.venv/lib/python3.11/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > Here's a concise executive briefing on recent breakthroughs in Tech, Health, and Finance:
#
# **Health:** Gene therapy is a rapidly advancing frontier, with recent successes in treating inherited hearing loss and sickle cell anemia. Within 5 years, expect wider applications for genetic diseases. CAR T-cell therapy shows promise for brain cancers, potentially impacting treatment within 3-7 years. Additionally, iPS cell-derived corneal transplants are restoring vision, with larger trials planned, suggesting broader eye disease applications in 5-10 years.
#
# **Tech:** Agentic AI, capable of autonomous workflow execution, is a major development with business impacts expected within 1-3 years. Advancements in quantum computing are progressing towards practical applications in material science and drug development, with potential impacts in 5-10 years.
#
# **Finance:** Digital assets and blockchain are transforming finance, with blockchain-based digital bonds and crypto banking services already operational and expanding. Stablecoins, backed by reserve requirements, are predicted to become a multi-trillion-dollar force within the next decade.
# FinanceResearcher > Here's your executive briefing for November 12, 2025:
#
# **Fintech Trends:**
#
# *   **Embedded Finance:** Integrating financial services into non-financial platforms is booming. Market implications include new revenue streams for non-financial companies and increased customer convenience. Expect this trend to continue scaling rapidly.
# *   **AI and Machine Learning:** AI is revolutionizing finance with automation, personalization, and fraud detection. Market impact sees enhanced efficiency and improved customer experiences. AI's role is expected to expand significantly across all financial services.
# *   **Biometrics and Cybersecurity:** Enhanced security measures, including biometrics, are critical. The market implication is increased trust and reduced fraud, with a growing emphasis on robust cybersecurity solutions to protect sensitive data.
#
# **Tech Trends:**
#
# *   **AI Agents:** These autonomous systems capable of learning and adapting are poised to have a major impact across industries. The market implication is a significant shift in how tasks are performed and decisions are made.
# *   **Spatial Computing:** Enabling interaction with virtual objects in physical environments, this trend, driven by AR/VR technologies, promises more immersive user experiences.
# *   **Energy-Efficient Computing:** Addressing the growing energy demands of computing, this trend focuses on sustainable and optimized processing power.
#
# **Health Trends:**
#
# *   **AI and Machine Learning in Healthcare:** Revolutionizing diagnostics, personalized treatments, and operational efficiency. Market impact includes more accurate diagnoses and streamlined processes.
# *   **Digital Home Monitoring & Virtual Care:** Shifting care from hospitals to homes, this trend enhances accessibility and patient engagement. The market sees a growing demand for remote patient monitoring and telehealth platforms.
# *   **Data Interoperability and Standardization:** Crucial for seamless data exchange between healthcare providers and systems to improve patient outcomes and reduce inefficiencies.
# TechResearcher > Here's a concise report on key AI/ML trends:
#
# **Key AI/ML Developments:**
#
# 1.  **Generative AI Beyond Chatbots:** Expanding beyond text generation to create complex multimedia content like images, video, and music.
# 2.  **Agentic AI:** AI systems designed to act autonomously and make decisions with minimal human oversight, transforming task execution and decision-making processes.
# 3.  **Explainable AI (XAI):** Focus on transparency in AI decision-making to build trust and meet regulatory requirements, particularly in sensitive sectors.
#
# **Main Companies Involved:**
#
# *   **Generative AI:** OpenAI, Google (Imagen, Muse), Microsoft, Anthropic.
# *   **Agentic AI:** Salesforce (Agentforce), Google, Microsoft.
# *   **Explainable AI:** Companies in healthcare and finance are prioritizing this.
# *   **General AI/ML:** Google, Microsoft, NVIDIA (hardware), Amazon, Meta.
#
# **Potential Impact:**
#
# These trends promise significant advancements in productivity, automation, and content creation across industries. However, they also raise ethical considerations regarding bias, data privacy, and the evolving job market. The increasing demand for AI solutions is driving substantial market growth and economic impact globally.
# AggregatorAgent > ## Executive Summary: Cross-Sector Innovations and the AI Revolution
#
# This briefing synthesizes key developments across technology, health, and finance, revealing a common thread of **AI-driven transformation** and the emergence of **autonomous systems**.
#
# **AI is the central theme:** Agentic AI, capable of autonomous decision-making and task execution, is poised for significant business impact within 1-3 years. This aligns with the broader trend of Generative AI expanding beyond text to create multimedia content, promising productivity gains and new creative avenues. In healthcare, AI and Machine Learning are revolutionizing diagnostics and personalized treatments, while in finance, they are enhancing automation, personalization, and fraud detection. Explainable AI (XAI) is gaining prominence across all sectors, crucial for building trust and meeting regulatory demands.
#
# **Healthcare is advancing rapidly:** Beyond AI, breakthroughs in gene therapy and CAR T-cell therapy offer new treatments for genetic diseases and brain cancers. iPS cell-derived corneal transplants also show promise for restoring vision. These health innovations are increasingly integrated with technological advancements like digital home monitoring and virtual care.
#
# **Finance is undergoing a digital overhaul:** Blockchain and digital assets are already reshaping financial services, with stablecoins projected to become a multi-trillion-dollar force. Embedded finance is integrating financial services into non-financial platforms, driving new revenue streams and customer convenience. Robust cybersecurity, including biometrics, is paramount in this evolving landscape.
#
# **Key Takeaways:**
# *   **AI and Agentic Systems are Disrupting All Sectors:** Expect significant shifts in how tasks are performed and decisions are made across industries.
# *   **Convergence of Technologies:** AI is enhancing health, finance, and creative industries, while also driving advancements in areas like quantum computing and energy-efficient processing.
# *   **Ethical Considerations are Paramount:** As AI becomes more integrated, addressing bias, data privacy, and job market impacts will be critical.

# %% [markdown]
# #### Loop Workflows - The Refinement Cycle

# %% [markdown]
# <img width="250" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/loop-agent.png" alt="Loop Agent" />

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_configs
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent,                                                                                                                                                                      ]
)

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "/home/poojan/programs/personal-programs/5dgai/.venv/lib/python3.11/site-packages/google/adk/agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias had known the lighthouse's granite bones intimately for thirty years. Each creak of the lantern room, each groan of the wind against the glass, was a familiar lullaby. One blustery Tuesday, while dusting the seldom-used archives in the basement, his fingers brushed against a loose stone. Behind it lay a rolled parchment, tied with faded crimson ribbon. Unfurling it, Elias gasped. It was a map, but unlike any he'd ever seen. The ink wasn't ink at all, but a shimmering, bioluminescent substance that pulsed with a soft, ethereal light. Strange symbols, reminiscent of ancient constellations, marked out a coastline that looked eerily like his own, yet subtly alien. A single, brilliant star pulsed at its center, a beacon on the paper itself. Elias, accustomed to the predictable rhythm of the sea, felt a tremor of something entirely new: wonder.
# CriticAgent > This is a strong start to a mystery! The description of Elias and his life at the lighthouse immediately establishes a sense of routine and isolation, making the discovery of the map all the more impactful. The map itself is described vividly, creating intrigue and a sense of the otherworldly.
#
# Here are a few suggestions for improvement:
#
# 1.  **Elaborate on Elias's reaction and internal thoughts:** While Elias's "wonder" is mentioned, delve deeper into what this feeling entails for a man who has lived a life of predictable rhythms. Does it manifest as fear, excitement, a sense of destiny, or a combination? Showing his internal struggle or burgeoning curiosity will make him a more relatable and engaging character.
# 2.  **Hint at the map's potential purpose or origin:** The map is described as "eerie" and "alien." Briefly hinting at *why* it might be there or what it could lead to would further enhance the mystery. Is it a treasure map, a guide to another realm, or something else entirely? Even a small suggestion can go a long way.
# 3.  **Consider adding a sensory detail beyond sight and sound:** We have the creaks and groans, and the visual of the glowing map. Could there be a subtle scent associated with the parchment, or a faint warmth emanating from the bioluminescent ink, to further immerse the reader in the discovery?
# RefinerAgent > Elias had known the lighthouse's granite bones intimately for thirty years. Each creak of the lantern room, each groan of the wind against the glass, was a familiar lullaby. His life was a steady, predictable tide, marked by the solemn sweep of the beam and the solitary communion with the gulls. One blustery Tuesday, while dusting the seldom-used archives in the damp, earth-scented basement, his fingers brushed against a loose stone. A tremor, not of the lighthouse but of his own dislodged routine, ran through him. Behind the stone lay a rolled parchment, tied with faded crimson ribbon.
#
# Unfurling it, Elias gasped, the sound swallowed by the basement's quiet. It was a map, but unlike any he'd ever seen. The ink wasn't ink at all, but a shimmering, bioluminescent substance that pulsed with a soft, ethereal light, casting strange, dancing shadows on the rough-hewn walls. A faint warmth emanated from the parchment, a stark contrast to the basement's chill. Strange symbols, reminiscent of ancient constellations, marked out a coastline that looked eerily like his own, yet subtly alien. A single, brilliant star pulsed at its center, a beacon on the paper itself, seeming to beckon him towards an unknown horizon.
#
# Elias, accustomed to the predictable rhythm of the sea, felt a tremor of something entirely new: a potent cocktail of fear and exhilaration. Wonder was too simple a word. This felt like destiny knocking, or perhaps a cosmic joke played by the universe. Was this a chart to forgotten riches? A guide to realms beyond human ken? Or a siren's call to a fate he couldn't comprehend? The parchment smelled faintly of ozone and something ancient, like stardust trapped for millennia. He traced the glowing lines, his heart thrumming a frantic counterpoint to the lighthouse's steady pulse, a profound curiosity ignited within him, a spark against the vast, dark ocean of the unknown.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %% [markdown]
# #### Choosing the Right Pattern
# #### Decision Tree: Which Workflow Pattern?

# %% [markdown]
# <img width="1000" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/agent-decision-tree.png" alt="Agent Decision Tree" />

# %% [markdown]
# ### Quick Reference Table
#
# | Pattern | When to Use | Example | Key Feature |
# |---------|-------------|---------|-------------|
# | **LLM-based (sub_agents)** | Dynamic orchestration needed | Research + Summarize | LLM decides what to call |
# | **Sequential** | Order matters, linear pipeline | Outline → Write → Edit | Deterministic order |
# | **Parallel** | Independent tasks, speed matters | Multi-topic research | Concurrent execution |
# | **Loop** | Iterative improvement needed | Writer + Critic refinement | Repeated cycles |

# %%
# Out:
#   Cell In[44], line 1
#     <img width="1000" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/agent-decision-tree.png" alt="Agent Decision Tree" />
#     ^
# SyntaxError: invalid syntax
